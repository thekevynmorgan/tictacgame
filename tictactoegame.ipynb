# %%
def print_board(board):
    print()
    for row in board:
        print(" | ".join(row))
        print("-" * 9)
    print()

def check_winner(board, player):
    # Check rows
    for row in board:
        if all(cell == player for cell in row):
            return True
    # Check columns
    for col in range(3):
        if all(board[row][col] == player for row in range(3)):
            return True
    # Check diagonals
    if all(board[i][i] == player for i in range(3)):
        return True
    if all(board[i][2-i] == player for i in range(3)):
        return True
    return False

def board_full(board):
    return all(all(cell != " " for cell in row) for row in board)

def main():
    board = [[" " for _ in range(3)] for _ in range(3)]
    current_player = "X"

    while True:
        print_board(board)
        print(f"Player {current_player}'s turn.")
        try:
            row = int(input("Enter row (1-3): ")) - 1
            col = int(input("Enter column (1-3): ")) - 1
        except ValueError:
            print("Invalid input. Please enter numbers 1-3.")
            continue

        if not (0 <= row <= 2 and 0 <= col <= 2):
            print("Row and column must be between 1 and 3.")
            continue
        if board[row][col] != " ":
            print("Cell already taken. Choose another one.")
            continue

        board[row][col] = current_player

        if check_winner(board, current_player):
            print_board(board)
            print(f"Player {current_player} wins!")
            break
        if board_full(board):
            print_board(board)
            print("It's a draw!")
            break

        # Switch player
        current_player = "O" if current_player == "X" else "X"

if __name__ == "__main__":
    main()
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
#
# Player X's turn.
# Enter row (1-3):  1
# Enter column (1-3):  2
#   | X |
# ---------
#   |   |
# ---------
#   |   |
# ---------
#
# Player O's turn.
# Enter row (1-3):  1
# Enter column (1-3):  1
# O | X |
# ---------
#   |   |
# ---------
#   |   |
# ---------
#
# Player X's turn.

# %%
def print_board(board):
    print("\n--- Tic-Tac-Toe Board ---") # Added a clean header
    for i, row in enumerate(board):
        # Join row cells with a ' | ' separator
        print(" | ".join(row))
        # Print separator line only between rows, not after the last row
        if i < 2: 
            # Changed the separator line to align better with ' | '
            print("---+---+---") 
    print() # Keep one blank line after the board for separation

def check_winner(board, player):
    # Check rows
    for row in board:
        if all(cell == player for cell in row):
            return True
    # Check columns
    for col in range(3):
        if all(board[row][col] == player for row in range(3)):
            return True
    # Check diagonals
    if all(board[i][i] == player for i in range(3)):
        return True
    if all(board[i][2-i] == player for i in range(3)):
        return True
    return False

def board_full(board):
    return all(all(cell != " " for cell in row) for row in board)

def main():
    board = [[" " for _ in range(3)] for _ in range(3)]
    current_player = "X"

    while True:
        print_board(board)
        print(f"Player {current_player}'s turn.")
        try:
            row = int(input("Enter row (1-3): ")) - 1
            col = int(input("Enter column (1-3): ")) - 1
        except ValueError:
            print("Invalid input. Please enter numbers 1-3.")
            continue

        if not (0 <= row <= 2 and 0 <= col <= 2):
            print("Row and column must be between 1 and 3.")
            continue
        if board[row][col] != " ":
            print("Cell already taken. Choose another one.")
            continue

        board[row][col] = current_player

        if check_winner(board, current_player):
            print_board(board)
            print(f"Player {current_player} wins!")
            break
        if board_full(board):
            print_board(board)
            print("It's a draw!")
            break

        # Switch player
        current_player = "O" if current_player == "X" else "X"

if __name__ == "__main__":
    main()
# Out:
# --- Tic-Tac-Toe Board ---
#   |   |
# ---+---+---
#   |   |
# ---+---+---
#   |   |
#
# Player X's turn.
# Enter row (1-3):  1
# Enter column (1-3):  2
# --- Tic-Tac-Toe Board ---
#   | X |
# ---+---+---
#   |   |
# ---+---+---
#   |   |
#
# Player O's turn.
# Enter row (1-3):  3
# Enter column (1-3):  3
# --- Tic-Tac-Toe Board ---
#   | X |
# ---+---+---
#   |   |
# ---+---+---
#   |   | O
#
# Player X's turn.

# %%
def print_board(board):
    print("\n--- Tic-Tac-Toe Board ---") # Added a clean header
    for i, row in enumerate(board):
        # Join row cells with a ' | ' separator
        print(" | ".join(row))
        # Print separator line only between rows, not after the last row
        if i < 2: 
            # Changed the separator line to align better with ' | '
            print("---+---+---") 
    print() # Keep one blank line after the board for separation

def check_winner(board, player):
    # Check rows
    for row in board:
        if all(cell == player for cell in row):
            return True
    # Check columns
    for col in range(3):
        if all(board[row][col] == player for row in range(3)):
            return True
    # Check diagonals
    if all(board[i][i] == player for i in range(3)):
        return True
    if all(board[i][2-i] == player for i in range(3)):
        return True
    return False

def board_full(board):
    return all(all(cell != " " for cell in row) for row in board)

# --- START OF CHANGE FOR COMMIT 3: New Helper Function ---
def switch_player(current_player):
    """Returns the other player."""
    return "O" if current_player == "X" else "X"
# --- END OF CHANGE FOR COMMIT 3 ---

def main():
    # Adding the welcome message from Commit 2, which was previously requested
    print("Welcome to Command Line Tic-Tac-Toe! Player X goes first.\n")
    
    board = [[" " for _ in range(3)] for _ in range(3)]
    current_player = "X"

    while True:
        print_board(board)
        print(f"Player {current_player}'s turn.")
        try:
            row = int(input("Enter row (1-3): ")) - 1
            col = int(input("Enter column (1-3): ")) - 1
        except ValueError:
            print("Invalid input. Please enter numbers 1-3.")
            continue

        if not (0 <= row <= 2 and 0 <= col <= 2):
            print("Row and column must be between 1 and 3.")
            continue
        if board[row][col] != " ":
            print("Cell already taken. Choose another one.")
            continue

        board[row][col] = current_player

        if check_winner(board, current_player):
            print_board(board)
            print(f"Player {current_player} wins!")
            break
        if board_full(board):
            print_board(board)
            print("It's a draw!")
            break

        # Switch player
        # --- CHANGE IN MAIN FOR COMMIT 3 ---
        current_player = switch_player(current_player)
        # --- END OF CHANGE IN MAIN FOR COMMIT 3 ---

if __name__ == "__main__":
    main()
# Out:
# Welcome to Command Line Tic-Tac-Toe! Player X goes first.
#
#
# --- Tic-Tac-Toe Board ---
#   |   |
# ---+---+---
#   |   |
# ---+---+---
#   |   |
#
# Player X's turn.
# Enter row (1-3):  2
# Enter column (1-3):  2
# --- Tic-Tac-Toe Board ---
#   |   |
# ---+---+---
#   | X |
# ---+---+---
#   |   |
#
# Player O's turn.
# Enter row (1-3):  2
# Enter column (1-3):  1
# --- Tic-Tac-Toe Board ---
#   |   |
# ---+---+---
# O | X |
# ---+---+---
#   |   |
#
# Player X's turn.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 78
#      75         # --- END OF CHANGE IN MAIN FOR COMMIT 3 ---
#      77 if __name__ == "__main__":
# ---> 78     main()
#
# Cell In[1], line 48, in main()
#      46 print(f"Player {current_player}'s turn.")
#      47 try:
# ---> 48     row = int(input("Enter row (1-3): ")) - 1
#      49     col = int(input("Enter column (1-3): ")) - 1
# ...

# %%
def print_board(board):
    print("\n--- Tic-Tac-Toe Board ---") # Added a clean header
    for i, row in enumerate(board):
        # Join row cells with a ' | ' separator
        print(" | ".join(row))
        # Print separator line only between rows, not after the last row
        if i < 2: 
            # Changed the separator line to align better with ' | '
            print("---+---+---") 
    print() # Keep one blank line after the board for separation

def check_winner(board, player):
    # Check rows
    for row in board:
        if all(cell == player for cell in row):
            return True
    # Check columns
    for col in range(3):
        if all(board[row][col] == player for row in range(3)):
            return True
    # Check diagonals
    if all(board[i][i] == player for i in range(3)):
        return True
    if all(board[i][2-i] == player for i in range(3)):
        return True
    return False

def board_full(board):
    return all(all(cell != " " for cell in row) for row in board)

def switch_player(current_player):
    """Returns the other player."""
    return "O" if current_player == "X" else "X"

def main():
    print("Welcome to Command Line Tic-Tac-Toe! Player X goes first.\n")
    
    board = [[" " for _ in range(3)] for _ in range(3)]
    current_player = "X"

    while True:
        print_board(board)
        print(f"Player {current_player}'s turn.")
        try:
            # --- START OF CHANGE FOR COMMIT 4 ---
            # Read input as 1-3 based numbers (row_input and col_input)
            row_input = int(input("Enter row (1-3): "))
            col_input = int(input("Enter column (1-3): "))
        except ValueError:
            print("Invalid input. Please enter numbers 1, 2, or 3.")
            continue
            
        # New: Validate the 1-3 range before converting to 0-2 index
        if not (1 <= row_input <= 3 and 1 <= col_input <= 3):
            print("Row and column must be between 1 and 3.")
            continue
            
        # Convert valid 1-3 input to 0-2 index
        row = row_input - 1
        col = col_input - 1
        
        # Original logic for 0-2 range check is now redundant and removed:
        # if not (0 <= row <= 2 and 0 <= col <= 2):
        #     print("Row and column must be between 1 and 3.")
        #     continue
        # --- END OF CHANGE FOR COMMIT 4 ---

        if board[row][col] != " ":
            print("Cell already taken. Choose another one.")
            continue

        board[row][col] = current_player

        if check_winner(board, current_player):
            print_board(board)
            print(f"Player {current_player} wins!")
            break
        if board_full(board):
            print_board(board)
            print("It's a draw!")
            break

        # Switch player
        current_player = switch_player(current_player)

if __name__ == "__main__":
    main()
# Out:
# Welcome to Command Line Tic-Tac-Toe! Player X goes first.
#
#
# --- Tic-Tac-Toe Board ---
#   |   |
# ---+---+---
#   |   |
# ---+---+---
#   |   |
#
# Player X's turn.
# Enter row (1-3):  4
# Enter column (1-3):  4
# Row and column must be between 1 and 3.
#
# --- Tic-Tac-Toe Board ---
#   |   |
# ---+---+---
#   |   |
# ---+---+---
#   |   |
#
# Player X's turn.
